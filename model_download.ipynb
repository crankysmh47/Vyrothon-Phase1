# %%
from deepface import DeepFace
# This will trigger the download and print the dimension (should be 128)
result = DeepFace.represent("any_local_image.jpg", model_name="Facenet", enforce_detection=False)
print("Dimension:", len(result[0]["embedding"]))
# Out:
# WARNING:tensorflow:From c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 26-04-18 11:25:12 - 🔗 facenet_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5 to C:\Users\Administrator\.deepface\weights\facenet_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5
# To: C:\Users\Administrator\.deepface\weights\facenet_weights.h5
# 100%|██████████| 92.2M/92.2M [00:59<00:00, 1.55MB/s]
# ---------------------------------------------------------------------------
# ImgNotFound                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from deepface import DeepFace
# ...
